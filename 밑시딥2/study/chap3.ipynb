# %%
import numpy as np

c = np.array([[1,0,0,0,0,0,0]])
w = np.random.randn(7,3)
h = np.matmul(c,w)

print(w)

print(h)
# Out:
# [[-0.68387116 -0.34208525  0.87129985]
#  [ 1.28006553 -0.20663955  1.65596288]
#  [ 0.64397388 -0.20256987  0.90120541]
#  [ 0.95427392  0.46099602  0.96522137]
#  [-0.13977841 -1.17702862  0.75054576]
#  [-0.02602667  1.65926693  1.24219583]
#  [ 1.50340736 -0.51497013 -1.00203118]]
# [[-0.68387116 -0.34208525  0.87129985]]

# %% [markdown]
# ### 여기서 보면 W의 첫 줄을 단순히 출력하는 것과 같다고 볼 수 있음.
# 그러면 행렬곱을 굳이 왜 쓰느냐? 나중 내용에서 공개된다고 하네요<br/>
# 아래도 같은 역할을 하는 애임

# %%
import sys
sys.path.append('..')
import numpy as np
from common.layers import MatMul

c = np.array([[1,0,0,0,0,0,0]])
w = np.random.randn(7,3)
layer = MatMul(w)
h = layer.forward(c)

print(w)
print(h)
# Out:
# [[-0.78500681 -0.1123232   0.78073241]
#  [-2.12695395  2.29888478  1.79594325]
#  [-1.66908774 -0.685088   -0.14135759]
#  [ 0.27171193  1.28449047 -0.8138922 ]
#  [ 2.16886185  0.68212239  0.71069972]
#  [ 0.06978142  1.05727913  0.25612586]
#  [-1.33258261 -0.43328459 -0.76596145]]
# [[-0.78500681 -0.1123232   0.78073241]]

# %% [markdown]
# ### 아래는 CBOW 모델을 기반으로 한 신경망 구성 파일이다. 구조는 아래와 같다.
# ![IMG_3516.jpeg](attachment:IMG_3516.jpeg)

# %%
import sys
sys.path.append('..')
import numpy as np
from common.layers import MatMul

c0 = np.array([[1,0,0,0,0,0,0]])
c1 = np.array([[0,0,1,0,0,0,0]])

w_in = np.random.randn(7,3)
w_out = np.random.randn(3,7)

in_layer0 = MatMul(w_in)
in_layer1 = MatMul(w_in)
out_layer = MatMul(w_out)

h0 = in_layer0.forward(c0)
h1 = in_layer1.forward(c1)
h = 0.5*(h0+h1)
s = out_layer.forward(h)

print(s)
# Out:
# [[ 1.16345293 -0.33589657  1.40050725 -0.72259863  0.3364608   0.18005918
#    0.59194148]]

# %% [markdown]
# ### 이후, 단순히 저렇게 출력하는 것 뿐만이 아니라 추론을 해내야하기 때문에 Softmax를 통해 확률을 얻어야 한다.
# ![IMG_3517.jpeg](attachment:IMG_3517.jpeg)
